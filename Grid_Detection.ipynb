# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
 flat_chess = cv2.imread('DATA/flat_chessboard.png')

# %%
plt.imshow(flat_chess)

# %%
found, corners = cv2.findCirclesGrid(flat_chess, (7, 7))

# %%
found
# Out:
# False

# %%
grid = cv2.drawChessboardCorners(flat_chess, (7,7), corners, found)

# %%
plt.imshow(grid)
